# %% [markdown]
# # 1. CatBoost CV

# %%
from src.common import load_config
from src.run_pipeline import run_cv

cfg = load_config("configs/catboost_v018_no_layout_id_core_tuned_holdout.yaml")
metrics = run_cv(cfg)
print(metrics)

# %% [markdown]
# # 1. LightGBM CV

# %%
from src.common import load_config
from src.run_pipeline import run_cv

cfg = load_config("configs/lightgbm_v010_no_layout_id_core_holdout_wide_leaves_balanced.yaml")
metrics = run_cv(cfg)
print(metrics)

# %%
from src.common import load_config
from src.run_pipeline import run_cv

cfg = load_config("configs/lightgbm_v011_no_layout_id_core_holdout_wider_leaves.yaml")
metrics = run_cv(cfg)
print(metrics)

# %% [markdown]
# # 1. 앙상블 제출 파일 생성

# %%
from src.common import load_config
from src.ensemble import run_ensemble

cfg = load_config("configs/blend_cb_lgbm_v001.yaml")
submission_path = run_ensemble(cfg)
print(submission_path)

# %% [markdown]
# # 1. 단일 모델 제출 파일 생성

# %%
from src.active_baselines import run_active_next_candidate

submission_path = run_active_next_candidate()
print(submission_path)

# %% [markdown]
# # 2. 스태킹 + 메타블렌드

# %%
from src.common import load_config
from src.stacking import run_stacking

cfg = load_config("configs/stack_lgb_meta_v003_log1p_family.yaml")
submission_path = run_stacking(cfg)
print(submission_path)

# %% [markdown]
# # 2. 타깃/손실 재설계

# %%
from src.common import load_config
from src.run_pipeline import run_cv

cfg = load_config("configs/lightgbm_v015_no_layout_id_core_holdout_log1p_adv_weighted.yaml")
metrics = run_cv(cfg)
print(metrics["oof_mae"])

# %% [markdown]
# # 3. layout_type expert

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 3. tail-aware loss-quantile

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 3. tail-aware loss-huber

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 3. pseudo-label

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 4. best stack 기반 residual modeling

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 4. scenario-relative feature family

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 5. context-aware stacking

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 5. v005 residual gate

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. 예측값 구간별 residual expert

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. residual_partition_experts

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. target-regime mixture

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. continuous_residual_gate

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. high-delay tail residual

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. scenario-relative 강화 residual family

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. context-aware stack 후속 residual

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. strong-family context-aware stacking v2

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. dual-base gate

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. dual-base gate v029 stack v005

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 6. error-selection gate

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. scenario-cluster residual experts

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. uncertainty-aware residual gate

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. scenario-neighbor residual

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. direct student

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. scenario baseline decomposition

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. CatBoost strong-family distillation

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. ExtraTrees strong-family distillation

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. scenario bias calibration

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. scenario order-statistics

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 7. monotonic / constrained direct model

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 8. bottleneck_states

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 9. residual feature pruning

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 9. regularization tuning

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 9. 보조 prediction source pruning

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])

# %% [markdown]
# # 9. blend v047 residual v029 shrinkage

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. lower-alpha shrinkage scan

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v049 residual v029 shrinkage fixed 090

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. layout_type별 shrinkage

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["alpha_by_layout_type"])

# %% [markdown]
# # 9. v029 예측값 구간별 shrinkage

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["alpha_by_band"])

# %% [markdown]
# # 9. abs(v029 - v021) 예측 차이 구간별 shrinkage

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["alpha_by_band"])

# %% [markdown]
# # 9. blend v053 v047 stack v006 diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v054 v045 stack v006 v021 diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v055 v053 v051 public proven

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v056 v053 v051 low band

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["alpha_by_band"])

# %% [markdown]
# # 9. blend v057 v053 v045 conservative

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v058 v053 prediction bias calibrated

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["per_bin_metrics"])

# %% [markdown]
# # 9. v053 단독 기반 prediction-bin residual calibration

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["per_bin_metrics"])

# %% [markdown]
# # 9. layout_type x prediction-bin별 median residual calibration

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["per_bin_metrics"])

# %% [markdown]
# # 9. blend v061 v053 layout type hierarchical bias calibrated

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["per_bin_metrics"])

# %% [markdown]
# # 9. blend v062 v053 layout type hierarchical bias crossfit

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["fold_scores"])
print(metrics["cross_fit"])

# %% [markdown]
# # 9. v053 90% + v023 10% conservative regime-diversity blend

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. v053 90% + v018 huber 10% conservative diversity blend

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. v053 85% + v018 9% + v023 6% capped dual diversity blend

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])

# %% [markdown]
# # 9. blend v066 v053 v018 v023 log dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])
print(metrics["prediction_space"])

# %% [markdown]
# # 9. blend v067 v053 v018 v023 power dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics["weights"])
print(metrics["prediction_space"])
print(metrics["prediction_power"])
print(metrics["prediction_offset"])

# %% [markdown]
# # 9. blend v068 v053 v018 v023 power shifted dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics.get("weights"))

# %% [markdown]
# # 9. blend v069 v053 v018 v023 strong power dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics.get("weights"))

# %% [markdown]
# # 9. blend v070 v053 v069 delta clip 100

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics)

# %% [markdown]
# # 9. blend v071 v053 v018 v023 raw expanded dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics.get("weights"))

# %% [markdown]
# # 9. blend v072 v053 v018 v023 raw capped20 dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics.get("weights"))

# %% [markdown]
# # 9. blend v073 v053 v018 v023 raw capped12 dual diversity

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
print(metrics["oof_mae"])
print(metrics.get("weights"))

# %% [markdown]
# # 9. v075 rank-space distribution-preserved blend

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
metrics

# %% [markdown]
# # 9. v076 v053 기반 seen layout_id residual calibration

# %%
from src.active_baselines import run_active_next_candidate_cv

metrics = run_active_next_candidate_cv()
metrics
